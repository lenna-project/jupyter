# %%
import io
from js import fetch
from PIL import Image
from numpy import asarray
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_141958/3220781004.py in <module>
#       1 import io
# ----> 2 from js import fetch
#       3 from PIL import Image
#       4 from numpy import asarray
#
# ModuleNotFoundError: No module named 'js'

# %%
resp = await fetch("https://raw.githubusercontent.com/lenna-project/lenna-plugins/main/lenna.png")
data = io.BytesIO((await resp.arrayBuffer()).to_py())
image = Image.open(data)
img = asarray(image)
print(img.shape)

# %%
import micropip
await micropip.install("https://lenna.app/cartoonify-plugin/lenna_cartoonify_plugin-0.1.1-cp38-cp38-linux_x86_64.whl")

# %%
import lenna_cartoonify_plugin
