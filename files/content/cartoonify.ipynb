# %%
from PIL import Image
from numpy import asarray

# %%
image = Image.open('assets/cartoonify.png')
data = asarray(image)
print(data.shape)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-5-2ce49dc1efdc> in <module>
# ----> 1 image = Image.open('assets/cartoonify.png')
#       2 data = asarray(image)
#       3 print(data.shape)
#
# /lib/python3.8/site-packages/PIL/Image.py in open(fp, mode, formats)
#    2889
#    2890     if filename:
# -> 2891         fp = builtins.open(filename, "rb")
#    2892         exclusive_fp = True
#    2893
#
# FileNotFoundError: [Errno 44] No such file or directory: 'assets/cartoonify.png'
